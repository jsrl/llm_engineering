# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest â ‹ pulling manifest â ™ pulling manifest â ¹ pulling manifest â ¸ pulling manifest â ¼ pulling manifest â ´ pulling manifest â ¦ pulling manifest â § pulling manifest â ‡ pulling manifest
# pulling dde5aa3fc5ff: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 2.0 GB
# pulling 966de95ca8a6: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 1.4 KB
# pulling fcc5a6bec9da: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 7.7 KB
# pulling a70ff7e570d9: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 6.0 KB
# pulling 56bb8bd477a5: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�   96 B
# pulling 34bb5ab01051: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can be used to generate high-quality content such as blog posts, social media posts, product descriptions, and more. This can help businesses save time and resources on content creation.
# 2. **Product Design and Development**: Generative AI can be used to design and develop new products, such as furniture, clothing, and electronics. It can also be used to generate 3D models and prototypes for prototyping and testing.
# 3. **Marketing and Advertising**: Generative AI can be used to generate personalized marketing campaigns, product recommendations, and social media ads.
# 4. **Customer Service and Support**: Generative AI-powered chatbots can be used to provide customer support, answer frequently asked questions, and route complex issues to human representatives.
# 5. **Data Analysis and Visualization**: Generative AI can be used to analyze large datasets, identify patterns, and generate visualizations to help businesses make data-driven decisions.
# 6. **Financial Modeling and Forecasting**: Generative AI can be used to build financial models, forecast revenue, and predict market trends.
# 7. **Supply Chain Optimization**: Generative AI can be used to optimize supply chain operations, including demand forecasting, inventory management, and logistics planning.
# 8. **Employee Onboarding and Training**: Generative AI-powered tools can be used to generate personalized onboarding materials, training content, and employee development programs.
# 9. **Sales Enablement**: Generative AI can be used to generate sales pitches, product information sheets, and other sales collateral.
# 10. **Predictive Maintenance**: Generative AI can be used to predict equipment failures, detect anomalies in maintenance data, and optimize maintenance schedules.
#
# Some specific examples of business applications of Generative AI include:
#
# * **Amazon's Generative AI-powered Content Recommendations**: Amazon uses generative AI to recommend products based on a user's browsing history and purchase behavior.
# * **Google's Generative AI-powered Image Search**: Google uses generative AI to generate images that match search queries, improving the accuracy of image search results.
# * **Microsoft's Generative AI-powered Chatbots**: Microsoft uses generative AI to power chatbots that provide customer support and answer frequently asked questions.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative use cases across various industries.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can be used to generate high-quality content such as articles, social media posts, product descriptions, and even entire books. This can save time and resources for businesses looking to create large volumes of content.
# 2. **Marketing Automation**: Generative AI can help automate marketing tasks such as email campaigns, ad copywriting, and social media posting. It can also analyze customer data and generate personalized marketing messages.
# 3. **Customer Service Chatbots**: Generative AI-powered chatbots can be used to provide 24/7 customer support, responding to common queries and routing complex issues to human representatives.
# 4. **Product Design and Development**: Generative AI can help designers create new product concepts, prototypes, and designs, saving time and resources in the design process.
# 5. **Data Analysis and Visualization**: Generative AI can be used to analyze large datasets and generate visualizations such as charts, graphs, and heat maps, helping businesses gain insights into customer behavior and market trends.
# 6. **Predictive Analytics**: Generative AI can be used to build predictive models that forecast sales, demand, and other business outcomes, enabling businesses to make data-driven decisions.
# 7. **Content Translation**: Generative AI can help translate content from one language to another, reducing the time and cost associated with human translation services.
# 8. **Image and Video Generation**: Generative AI can be used to generate images and videos for use in marketing campaigns, advertising, and other applications.
# 9. **Music and Audio Generation**: Generative AI can be used to create music and audio content for use in various applications such as advertising, video games, and film scores.
# 10. **Automated Content Moderation**: Generative AI can help moderate online content by detecting and flagging potentially objectionable material, reducing the workload of human moderators.
#
# In addition to these specific business applications, generative AI has the potential to transform entire industries, including:
#
# * **Manufacturing**: Generating blueprints, designs, and production plans.
# * **Finance**: Analyzing financial data and generating investment recommendations.
# * **Healthcare**: Developing personalized treatment plans and predicting patient outcomes.
# * **Education**: Creating customized learning materials and assessments.
#
# Overall, generative AI has the potential to revolutionize business operations by automating repetitive tasks, improving efficiency, and enabling new forms of innovation and creativity.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has various business applications across industries, including:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as images, videos, music, and text, which can be used for marketing campaigns, influencer collaboration, or creating engaging social media content.
# 2. **Marketing Automation**: Generative AI can help automate tasks such as lead generation, email automation, and customer engagement, improving the efficiency and personalization of marketing efforts.
# 3. **User Experience (UX) Design**: Generative AI can be used to generate design prototypes and conceptualize new product ideas based on user feedback and market trends.
# 4. **Predictive Analytics**: Generative AI algorithms can analyze vast amounts of data to predict future trends, sentiment, and behavior, enabling informed business decisions in sectors like finance, healthcare, and retail.
# 5. **Automated Customer Service**: Generative AI-powered chatbots can provide 24/7 customer support, helping businesses improve response times and satisfaction levels.
# 6. **Data Annotation**: Generative AI can assist with data annotation tasks, reducing the need for manual labeling and improving machine learning model performance.
# 7. **Product Development**: Generative AI can generate new product designs or identify design flaws by simulating various scenarios and testing hypotheses.
# 8. **Finance and Risk Analysis**: Generative AI algorithms can analyze complex financial datasets to detect anomalies, predict market behavior, and optimize investment strategies.
# 9. **Healthcare**: Generative AI can help create personalized patient models for clinicians, generate medical imaging analytics, or identify patterns in genomic data that can lead to breakthroughs in disease diagnosis.
# 10. **Supply Chain Optimization**: Generative AI can analyze procurement, logistics, and inventory management data to predict demand, optimize inventories, and reduce waste.
# 11. **Document Review and Signing**: Generative AI-powered contract review tools can help reduce errors, speed up the contracting process, and provide personalized recommendations for contract law experts.
# 12. **Human Resources (HR) Talent Pool Management**: Generative AI can generate candidate resumes that conform to specific requirements, creating a more efficient and effective talent acquisition workflow.
#
# Some notable corporate examples that have successfully integrated generative AI into their operations include:
#
# *   **SAP**, which uses generative AI to create personalized training programs for its customers
# *   **IBM Watson**, which developed a virtual reality business experience with the power of Generative AI algorithms.

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, so I need to figure out how to respond to this user who is asking about a few concepts related to Large Language Models (LLMs). Specifically, they're interested in defining "neural networks" as an underpinning, and two other core ideas: attention and the transformer. Hmm, that's interesting because these are big areas of AI research.
#
# First off, I should probably start by understanding what a neural network is within the context of LLMs. Neural networks are commonly referred to in discussions of machine learning at large, but when applied specifically to NLP tasks like language modeling or machine translation, they're called LLMs. So, maybe I can break this down into an overview that explains how they work with layers and nodes, including the core components.
#
# Next, attention seems crucial for LLMs because it allows models to focus on specific parts of text in a way that captures context sensitivity. I should explain what attention modules do—how they compute attention weights, which determine where the model assigns most weight. Their implementation might involve mechanisms like scaled dot-product or soft-max functions, as these are how nodes decide their output dependencies.
#
# Then, the transformer is another key component of many LLMs. Unlike typical recursive neural networks that have repetitive layers and fixed depths, transformers use a deeper, self-attention mechanism with multi-head attention. This allows each model head to focus on different aspects or positions in the input sequence simultaneously. The position-aware decoder also builds attention across the sequence in real-time as it processes each token could be another important point.
#
# Wait, but maybe I should also explain why transformers are so important for LLMs. They've been winning many NLP challenges because they efficiently handle context through self-attention and can process large sequences effectively. This efficiency and ability to model long-range dependencies make them suitable for generating text or understanding complex sentences.
#
# I should structure the response clearly, separating each concept with a heading. Make sure each definition is clear but not too technical so that someone without deep expertise in AI can understand it. Also, keeping it conversational might help the user who hasn't done much reading on this topic yet.
#
# Let me think if there's anything I'm missing about LLMs as neural networks? Maybe their ability to learn and adapt quickly through training data—neayers, perhaps that's a different aspect but still relevant under the broader definition of them being neural networks in applied contexts.
#
# I should ensure each point is concise. Start with an overview, then delve into attention, followed by transformers, maybe touch on how all these aspects work together to create LLMs for various tasks like translation or creative writing.
#
# Okay, I think that's a good plan. Time to put it all together in a clear and informative way.
# </think>
#
# Certainly! Let's explore the core concepts behind Large Language Models (LLMs) with an organized and insightful approach:
#
# ### Overview of Neural Networks as Underlying LLMs
#
# Neural networks are computational systems designed at scale for processing information, inspired by the structure and function of biological neural systems. In the context of NLP, while traditional neural networks are often referred to as language models, these are specifically designed with layers and nodes optimized for capturing complex patterns in textual data. They are particularly effective when trained on large datasets, enabling them to learn intricate relationships between words and context.
#
# ### Key Components of Neural Networks
#
# A typical neural network consists of multiple layers (intrinsic dimension), each containing numerous nodes that process incoming signals with adjustable weights. These nodes perform operations like activation functions or matrix multiplications, transforming inputs into outputs that can capture contextual features.
#
# ---
#
# ### The Role of Attention in LLMs
#
# Attention is a fundamental mechanism within LLMs that allows models to focus on specific parts of input data. It works by computing attention weights that indicate how much each word contributes to the model's processing of another word. This dynamic approach ensures models emphasize the most relevant context when making predictions or generating outputs.
#
# ### The Transformer Model
#
# The transformer is a game-changing component in many LLMs, replacing traditional recurrent neural networks (RNNs) with self-attention mechanisms. It uses multi-head attention to process input sequences efficiently by decomposing dependencies across different positions and simultaneously building real-time attention scores as tokens are processed. This deep, self-referential mechanism enables the model to learn long-range correlations effectively.
#
# ---
#
# ### Why Transformers are Effective in LLMs
#
# Transformers are particularly effective because they reduce reliance on sequential processing through their self-attention mechanism. They can handle variable-length sequences and adapt to varying input sizes without explicit design limits, making them highly efficient for tasks like translation or creative writing. The transformer's ability to model context at each position across the entire sequence also enhances its capacity to generate coherent outputs.
#
# ---
#
# This overview highlights how neural networks, attention, and transformers together form the backbone of modern LLMs, enabling their ability to understand, generate, and adapt complex texts effectively.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.
